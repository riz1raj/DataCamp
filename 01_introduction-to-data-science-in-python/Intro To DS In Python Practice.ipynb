# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("E:\Jupyter Notebooks\Dataset/Admission_Predict.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# To get the basic info abt the number of columns, datatypes of columns, non-null values, number of entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Selecting a column trick 1
age = df['age']
print(age)
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
# Selecting a column trick 2
age_1 = df.age
print(age_1)
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
# Selecting specific ROWS
# to print all the values with TRUE and FALSE

df.age > 20
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1333     True
# 1334    False
# 1335    False
# 1336     True
# 1337     True
# Name: age, Length: 1338, dtype: bool

# %%
# Selecting specific ROWS
# to print "ONLY THE TRUE" the values with all the columns

df[df.age > 20]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# ...   ...     ...     ...       ...    ...        ...          ...
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1172 rows x 7 columns]

# %%
# When assigning " == " sign, we dont need to use ""

sup = df[df.age == 23]
print(sup)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 12     23    male  34.400         0     no  southwest   1826.84300
# 17     23    male  23.845         0     no  northeast   2395.17155
# 28     23    male  17.385         1     no  northwest   2775.19215
# 240    23  female  36.670         2    yes  northeast  38511.62830
# 358    23    male  41.910         0     no  southeast   1837.28190
# 375    23  female  28.310         0    yes  northwest  18033.96790
# 479    23    male  32.560         0     no  southeast   1824.28540
# 643    23  female  34.960         3     no  northwest   4466.62140
# 699    23  female  39.270         2     no  southeast   3500.61230
# 738    23    male  31.730         3    yes  northeast  36189.10170
# 761    23    male  35.200         1     no  southwest   2416.95500
# 804    23    male  26.510         0     no  southeast   1815.87590
# 817    23    male  37.100         3     no  southwest   3597.59600
# ...

# %%
df[df.age == 23]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 12     23    male  34.400         0     no  southwest   1826.84300
# 17     23    male  23.845         0     no  northeast   2395.17155
# 28     23    male  17.385         1     no  northwest   2775.19215
# 240    23  female  36.670         2    yes  northeast  38511.62830
# 358    23    male  41.910         0     no  southeast   1837.28190
# 375    23  female  28.310         0    yes  northwest  18033.96790
# 479    23    male  32.560         0     no  southeast   1824.28540
# 643    23  female  34.960         3     no  northwest   4466.62140
# 699    23  female  39.270         2     no  southeast   3500.61230
# 738    23    male  31.730         3    yes  northeast  36189.10170
# 761    23    male  35.200         1     no  southwest   2416.95500
# 804    23    male  26.510         0     no  southeast   1815.87590
# 817    23    male  37.100         3     no  southwest   3597.59600
# ...

# %%
# line Plot
plt.figure(figsize=(20,10))
plt.plot(df['age'], df['children'])

# %%
plt.figure(figsize=(20,5))
plt.plot(df['age'])
plt.plot(df['children'])

# %% [markdown]
# ## Q) Which Officer Did NOT Start Working Untill Wednesday?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  ANS: Green Line is the answer as it is constant till tuesday

# %%
# line Plot
plt.figure(figsize=(10,5))
plt.plot(df['age'])
plt.plot(df['children'])

# Add a title
plt.title("title")
# Add y-axis label
plt.ylabel("label")
# Add x-axis label
plt.xlabel("label")

# Add annotation "Missing data" at (10,10)
plt.text(10, 10, "Missing data")
# Out:
# Text(10, 10, 'Missing data')

# %%
plt.figure(figsize = (20,5))
plt.plot(df['age'])
#plt.style.use('fivethirtyeight')
plt.style.use('ggplot')
#plt.style.use('seaborn')
#plt.style.use('default')
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.plot(df['age'], label="AGE", linestyle=":", marker = "s")

# %%
# plt.plot(x, y, label='Ransom', linestyle=':', color='gray')

# %%
# SCATTER PLOT, alpha is for TRANSPARENCY LEVEL

plt.scatter(df['age'], df['charges'], color='red', marker='s', alpha=0.1)

plt.ylabel('Age')
plt.xlabel('Charges')
# Out:
# Text(0.5, 0, 'Charges')

# %%
plt.figure(figsize=(20,10))
plt.bar(df['age'], df['children'])
plt.show()
